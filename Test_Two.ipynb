# %% [markdown]
# <a href="https://colab.research.google.com/github/lyricabdulrasheed/Twest-2/blob/main/Test_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset

# %% [markdown]
# 1. Perform data inspection and identify any missing or inconsistent values.

# %%
import pandas as pd

#This line imports the pandas library, which is a powerful tool for data analysis in Python.
#It provides data structures and functions for working with tabular data.

# Replace 'your_file.xlsx' with the actual path to your Excel file
df = pd.read_excel('Test2_dataset (1).xlsx')

# Print the first few rows of the DataFrame
print(df.head())

#This line prints the first five rows of the DataFrame.
#This gives you a quick overview of the data, including the column names and sample values.
# Out:
#              Catalyst  Ratio of CH4 in Feed  Reaction Temperature  Ni Loading  \
# 0         Ni−SiO2‑550                  0.15                   650        10.0
# 1         Ni−SiO2‑750                  0.15                   650        10.0
# 2   Ni/Sn0.2−SiO2‑550                  0.15                   650        10.0
# 3   Ni/Sn0.2−SiO2‑750                  0.15                   650        10.0
# 4  Ni/Sn0.05−SiO2‑550                  0.15                   650        10.0
#
#    Reaction Time  Pore Size  Pore Volume  Surface Area  \
# 0            0.5        4.7         0.58         476.0
# 1            0.5        4.7         0.58         476.0
# 2            0.5        5.2         0.58         455.0
# 3            0.5        5.2         0.58         455.0
# 4            0.5        4.8         0.82         599.0
#
#    H2-TPR Peak Temperature  Ni Particle Size  Ni Dispersion  \
# 0                    640.0               2.9            NaN
# ...

# %%
# Assuming you have a DataFrame named 'df'
print(df.info())

#This line uses the print function to display information about the DataFrame df.
#The .info() method is called on the DataFrame object df.

#It provides a summary of the DataFrame, including the number of rows and columns,
#the data types of each column, and the number of non-null values in each column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1714 entries, 0 to 1713
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Catalyst                    1714 non-null   object
#  1   Ratio of CH4 in Feed        1714 non-null   float64
#  2   Reaction Temperature        1714 non-null   int64
#  3   Ni Loading                  1714 non-null   float64
#  4   Reaction Time               1714 non-null   float64
#  5   Pore Size                   1714 non-null   float64
#  6   Pore Volume                 1714 non-null   float64
#  7   Surface Area                1714 non-null   float64
#  8   H2-TPR Peak Temperature     1714 non-null   float64
#  9   Ni Particle Size            1714 non-null   float64
#  10  Ni Dispersion               658 non-null    float64
#  11  Modifier Electronegativity  1714 non-null   float64
#  12  GHSV                        1714 non-null   int64
# ...

# %%
# Checking for any missing values
missing_values = df.isnull().sum()

print("Number of missing values in each column:")
print(missing_values)

#This line prints a message indicating that the following output will show the number of missing values in each column.
#This prints the missing_values Series, which contains the count of missing values for each column in the original DataFrame df.
# Out:
# Number of missing values in each column:
# Catalyst                         0
# Ratio of CH4 in Feed             0
# Reaction Temperature             0
# Ni Loading                       0
# Reaction Time                    0
# Pore Size                        0
# Pore Volume                      0
# Surface Area                     0
# H2-TPR Peak Temperature          0
# Ni Particle Size                 0
# Ni Dispersion                 1056
# Modifier Electronegativity       0
# GHSV                             0
# CH4 Conversion                  49
# CO2 Conversion                  77
# Syngas_Ratio                    76
# dtype: int64

# %% [markdown]
# 2. Handle any missing data using appropriate techniques (e.g., fill missing values or remove incomplete rows).

# %%
# Removing any missing values - for this case we do not have any, but I would
# like to write the code to removing any for practice.

# Remove rows with any missing values
df_cleaned = df.dropna(how='any')

#df.dropna(): This function is used to remove rows or columns containing missing values from the DataFrame df.
#how='any': This specifies that a row or column should be dropped if any of its values are missing.
#You can also use how='all' to drop only rows or columns where all values are missing.

#df_cleaned =: This assigns the result of the dropna() operation to a new DataFrame named df_cleaned.
#This creates a copy of the original DataFrame with missing values removed.

# Print the cleaned DataFrame
print(df_cleaned)

#This line prints the df_cleaned DataFrame, showing the data after removing rows with missing values.
# Out:
#              Catalyst  Ratio of CH4 in Feed  Reaction Temperature  Ni Loading  \
# 17     3%-Ni/(-Al2O3)                  0.15                   800        4.09
# 18     5%-Ni/(-Al2O3)                  0.15                   800        4.68
# 19    10%-Ni/(-Al2O3)                  0.15                   800        3.64
# 20    20%-Ni/(-Al2O3)                  0.15                   800        4.23
# 21     3%-Ni/(-Al2O3)                  0.15                   800        4.09
# ...               ...                   ...                   ...         ...
# 1705         NCMZ (■)                  0.50                   750        3.00
# 1706          NMZ (▴)                  0.50                   750        6.00
# 1707           Ni-DHT                  0.50                   750        3.97
# 1708           Ni-GRF                  0.50                   750        3.83
# 1709           Ni-IMP                  0.50                   750        4.24
#
# ...

# %% [markdown]
# 3. Apply data transformation techniques, such as normalization or encoding categorical variables, to prepare the data for machine learning tasks.

# %%
import pandas as pd

# Load your dataset (replace 'your_data.csv' with the actual path)
df = pd.read_excel('Test2_dataset (1).xlsx')

# Identify categorical variables
categorical_columns = df.select_dtypes(include=['object']).columns

# Apply one-hot encoding
df_encoded = pd.get_dummies(df, columns=categorical_columns)

# Print the encoded DataFrame
print(df_encoded)
# Out:
#       Ratio of CH4 in Feed  Reaction Temperature  Ni Loading  Reaction Time  \
# 0                     0.15                   650       10.00            0.5
# 1                     0.15                   650       10.00            0.5
# 2                     0.15                   650       10.00            0.5
# 3                     0.15                   650       10.00            0.5
# 4                     0.15                   650       10.00            0.5
# ...                    ...                   ...         ...            ...
# 1709                  0.50                   750        4.24           72.0
# 1710                  0.50                   700        5.00            3.0
# 1711                  0.50                   700        5.00            3.0
# 1712                  0.50                   700        5.00            3.0
# 1713                  0.50                   700        5.00            3.0
#
# ...

# %% [markdown]
# 4. Generate summary statistics (mean, median, standard deviation, etc.) for the dataset.

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
# Replace 'your_data.csv' with the actual path to your dataset
df = pd.read_excel('Test2_dataset (1).xlsx')

# Calculate the desired statistics for each numeric column
for column in df.select_dtypes(include='number').columns:
    mean = df[column].mean()
    median = df[column].median()
    std_dev = df[column].std()
    minimum = df[column].min()
    maximum = df[column].max()
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1

    print(f"\nColumn: {column}")
    print(f"Mean: {mean:.2f}")
    print(f"Median: {median:.2f}")
    print(f"Standard Deviation: {std_dev:.2f}")
    print(f"Minimum: {minimum:.2f}")
    print(f"Maximum: {maximum:.2f}")
    print(f"Interquartile Range (IQR): {iqr:.2f}")
# Out:
# Column: Ratio of CH4 in Feed
# Mean: 0.37
# Median: 0.40
# Standard Deviation: 0.15
# Minimum: 0.05
# Maximum: 0.50
# Interquartile Range (IQR): 0.25
#
# Column: Reaction Temperature
# Mean: 703.48
# Median: 700.00
# Standard Deviation: 86.78
# Minimum: 400.00
# Maximum: 1000.00
# Interquartile Range (IQR): 100.00
#
# Column: Ni Loading
# Mean: 9.34
# Median: 9.67
# Standard Deviation: 5.71
# Minimum: 0.30
# Maximum: 60.00
# Interquartile Range (IQR): 5.22
#
# Column: Reaction Time
# Mean: 16.29
# Median: 7.00
# Standard Deviation: 22.75
# Minimum: 0.10
# Maximum: 200.00
# Interquartile Range (IQR): 23.50
#
# Column: Pore Size
# Mean: 11.57
# Median: 8.30
# Standard Deviation: 10.58
# Minimum: 0.50
# Maximum: 167.00
# Interquartile Range (IQR): 8.80
#
# Column: Pore Volume
# Mean: 0.40
# Median: 0.36
# Standard Deviation: 0.29
# Minimum: 0.00
# Maximum: 2.90
# Interquartile Range (IQR): 0.37
#
# Column: Surface Area
# Mean: 188.48
# Median: 143.88
# Standard Deviation: 174.10
# ...

# %% [markdown]
# 5. Create visualizations (scatter plots, histograms, box plots) to identify trends and relationships between variables.

# %%
# Import the matplotlib.pyplot module
import matplotlib.pyplot as plt

# Get a list of numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns

# Create subplots for histograms and box plots
fig, axes = plt.subplots(nrows=len(numeric_columns),
 ncols=2, figsize=(12, 6 * len(numeric_columns)))

# Iterate over numeric columns
for i, column in enumerate(numeric_columns):
    # Histogram
    axes[i, 0].hist(df[column], bins=20)
    axes[i, 0].set_title(f"Histogram of {column}")
    axes[i, 0].set_xlabel(column)
    axes[i, 0].set_ylabel("Frequency")

    # Box plot
    axes[i, 1].boxplot(df[column])
    axes[i, 1].set_title(f"Box Plot of {column}")
    axes[i, 1].set_ylabel(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# 6. Analyze the correlations between features and target variables (CH₄ Conversion, CO₂ Conversion, and Syngas Ratio).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_excel('Test2_dataset (1).xlsx')

# Select only numeric columns
numeric_columns = df.select_dtypes(include='number').columns
# Calculate the correlation matrix
correlation_matrix = df[numeric_columns].corr()

# Print the correlation matrix
print(correlation_matrix)
# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='viridis')

plt.title('Correlation Matrix')
plt.show()
# Out:
#                             Ratio of CH4 in Feed  Reaction Temperature  \
# Ratio of CH4 in Feed                    1.000000              0.042877
# Reaction Temperature                    0.042877              1.000000
# Ni Loading                              0.069500             -0.043081
# Reaction Time                          -0.028092              0.252815
# Pore Size                              -0.004645             -0.021182
# Pore Volume                             0.042344             -0.014078
# Surface Area                            0.079162             -0.005833
# H2-TPR Peak Temperature                -0.010308              0.097387
# Ni Particle Size                       -0.054405              0.047700
# Ni Dispersion                          -0.022281              0.019450
# Modifier Electronegativity             -0.022700             -0.009668
# GHSV                                   -0.090410              0.094654
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, f_regression
# Load your dataset

df = pd.read_excel('Test2_dataset (1).xlsx') # Changed the filename to 'cleaned_data.csv'

# Explore the data
print(df.head())  # Display the first few rows
print(df.info())  # Get information about data types and missing values
print(df.describe())  # Get summary statistics

# Visualize data distributions
for column in df.select_dtypes(include='number').columns:
    sns.histplot(df[column])
    plt.title(f"Histogram of {column}")
    plt.show()

# Analyze relationships between variables
# Select only numeric columns for correlation analysis
numeric_df = df.select_dtypes(include='number')
correlation_matrix = numeric_df.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='viridis')
plt.title("Correlation Matrix")
plt.show()
# Out:
#              Catalyst  Ratio of CH4 in Feed  Reaction Temperature  Ni Loading  \
# 0         Ni−SiO2‑550                  0.15                   650        10.0
# 1         Ni−SiO2‑750                  0.15                   650        10.0
# 2   Ni/Sn0.2−SiO2‑550                  0.15                   650        10.0
# 3   Ni/Sn0.2−SiO2‑750                  0.15                   650        10.0
# 4  Ni/Sn0.05−SiO2‑550                  0.15                   650        10.0
#
#    Reaction Time  Pore Size  Pore Volume  Surface Area  \
# 0            0.5        4.7         0.58         476.0
# 1            0.5        4.7         0.58         476.0
# 2            0.5        5.2         0.58         455.0
# 3            0.5        5.2         0.58         455.0
# 4            0.5        4.8         0.82         599.0
#
#    H2-TPR Peak Temperature  Ni Particle Size  Ni Dispersion  \
# 0                    640.0               2.9            NaN
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_excel('Test2_dataset (1).xlsx')

# Explore the data
print(df.head())
print(df.describe())

# Check for correlations - Excluding non-numeric columns
correlation_matrix = df.select_dtypes(include=['number']).corr() # Select only numeric columns for correlation calculation
print(correlation_matrix)

# Visualize correlations
sns.heatmap(correlation_matrix, annot=True, cmap="viridis")
plt.title("Correlation Matrix")
plt.show()

# Identify strong correlations
strong_correlations = correlation_matrix[(correlation_matrix > 0.7) | (correlation_matrix < -0.7)]
print("Strong Correlations:")
print(strong_correlations)
# Out:
#              Catalyst  Ratio of CH4 in Feed  Reaction Temperature  Ni Loading  \
# 0         Ni−SiO2‑550                  0.15                   650        10.0
# 1         Ni−SiO2‑750                  0.15                   650        10.0
# 2   Ni/Sn0.2−SiO2‑550                  0.15                   650        10.0
# 3   Ni/Sn0.2−SiO2‑750                  0.15                   650        10.0
# 4  Ni/Sn0.05−SiO2‑550                  0.15                   650        10.0
#
#    Reaction Time  Pore Size  Pore Volume  Surface Area  \
# 0            0.5        4.7         0.58         476.0
# 1            0.5        4.7         0.58         476.0
# 2            0.5        5.2         0.58         455.0
# 3            0.5        5.2         0.58         455.0
# 4            0.5        4.8         0.82         599.0
#
#    H2-TPR Peak Temperature  Ni Particle Size  Ni Dispersion  \
# 0                    640.0               2.9            NaN
# ...
